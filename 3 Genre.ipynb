# %% [markdown]
# Msost Played Genre

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

# %%
df["genre"].value_counts() .head(10)
# Out:
# genre
# Misc            9304
# Action          8557
# Adventure       6260
# Role-Playing    5721
# Sports          5586
# Shooter         5410
# Platform        4001
# Strategy        3685
# Puzzle          3521
# Racing          3425
# Name: count, dtype: int64

# %%
df[(df.console == "PC")&(df.genre == "Misc")] .iloc[:,3] .value_counts()
# Out:
# genre
# Misc    1375
# Name: count, dtype: int64

# %% [markdown]
# ###

# %%
#Most played Genre on PC

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'PC') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on PC", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'PS2') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on PS2", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'DS') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on DS", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'PS4') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on PS4", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'PS') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on PS", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'NS') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on NS(Nintendo Switch)", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'XBL') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on XBL(Xbox Live)", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'PSN') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on PSN(Play Station Network)", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'XOne') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on XOne", ylabel = "" )

#print(value_counts)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('vgchartz-2024.csv')
df = dataset

filtered_df = df[(df['console'] == 'PS3') & 
                 (df['genre'].isin(['Misc', 'Action', 'Adventure', 'Role-Playing', 'Sports', 'Shooter', 'Platform', 'Strategy', 'Puzzle', 'Racing']))]

# Count the occurrences of each unique value in the filtered DataFrame
value_counts = filtered_df['genre'].value_counts() .plot(kind = "pie",autopct = "%1.1f%%", title = "Most played Genre on PS3", ylabel = "" )

#print(value_counts)
